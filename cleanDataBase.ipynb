# %%
# Dependencies
import json
import requests 
import pandas as pd

# %%
access_token = 4385506478176069

url = "https://superheroapi.com/api/" + str(access_token) +"/"

# %%
# Make request and store response
response_json = []
for id in range(1,731):
    api_url = url + str(id)
    response = requests.get(api_url)

    response_json.append(response.json())
# Print status code
#print(response.status_code)

# %%
json_df = pd.DataFrame(response_json)
json_df
# Out:
#     response   id             name  \
# 0    success    1           A-Bomb
# 1    success    2       Abe Sapien
# 2    success    3         Abin Sur
# 3    success    4      Abomination
# 4    success    5          Abraxas
# ..       ...  ...              ...
# 725  success  726     Yellowjacket
# 726  success  727  Yellowjacket II
# 727  success  728             Ymir
# 728  success  729             Yoda
# 729  success  730          Zatanna
#
#                                             powerstats  \
# 0    {'intelligence': '38', 'strength': '100', 'spe...
# 1    {'intelligence': '88', 'strength': '28', 'spee...
# 2    {'intelligence': '50', 'strength': '90', 'spee...
# 3    {'intelligence': '63', 'strength': '80', 'spee...
# 4    {'intelligence': '88', 'strength': '63', 'spee...
# ..                                                 ...
# 725  {'intelligence': '88', 'strength': '10', 'spee...
# 726  {'intelligence': '50', 'strength': '10', 'spee...
# 727  {'intelligence': '50', 'strength': '100', 'spe...
# 728  {'intelligence': '88', 'strength': '52', 'spee...
# 729  {'intelligence': '81', 'strength': '10', 'spee...
#
#                                              biography  \
# 0    {'full-name': 'Richard Milhouse Jones', 'alter...
# 1    {'full-name': 'Abraham Sapien', 'alter-egos': ...
# 2    {'full-name': '', 'alter-egos': 'No alter egos...
# 3    {'full-name': 'Emil Blonsky', 'alter-egos': 'N...
# 4    {'full-name': 'Abraxas', 'alter-egos': 'No alt...
# ..                                                 ...
# 725  {'full-name': 'Hank Pym', 'alter-egos': 'Ant-M...
# 726  {'full-name': 'Rita DeMara', 'alter-egos': 'No...
# 727  {'full-name': 'Ymir', 'alter-egos': 'No alter ...
# 728  {'full-name': 'Yoda', 'alter-egos': 'No alter ...
# 729  {'full-name': 'Zatanna Zatara', 'alter-egos': ...
#
#                                             appearance  \
# 0    {'gender': 'Male', 'race': 'Human', 'height': ...
# 1    {'gender': 'Male', 'race': 'Icthyo Sapien', 'h...
# 2    {'gender': 'Male', 'race': 'Ungaran', 'height'...
# 3    {'gender': 'Male', 'race': 'Human / Radiation'...
# 4    {'gender': 'Male', 'race': 'Cosmic Entity', 'h...
# ..                                                 ...
# 725  {'gender': 'Male', 'race': 'Human', 'height': ...
# 726  {'gender': 'Female', 'race': 'Human', 'height'...
# 727  {'gender': 'Male', 'race': 'Frost Giant', 'hei...
# 728  {'gender': 'Male', 'race': 'Yoda's species', '...
# 729  {'gender': 'Female', 'race': 'Human', 'height'...
#
#                                                   work  \
# 0    {'occupation': 'Musician, adventurer, author; ...
# 1    {'occupation': 'Paranormal Investigator', 'bas...
# 2    {'occupation': 'Green Lantern, former history ...
# 3           {'occupation': 'Ex-Spy', 'base': 'Mobile'}
# 4    {'occupation': 'Dimensional destroyer', 'base'...
# ..                                                 ...
# 725  {'occupation': 'Adventurer, Biochemist, former...
# 726  {'occupation': 'Adventurer; former criminal, e...
# 727          {'occupation': '-', 'base': 'Niffleheim'}
# 728                   {'occupation': '-', 'base': '-'}
# 729                   {'occupation': '-', 'base': '-'}
#
#                                            connections  \
# 0    {'group-affiliation': 'Hulk Family; Excelsior ...
# 1    {'group-affiliation': 'Bureau for Paranormal R...
# 2    {'group-affiliation': 'Green Lantern Corps, Bl...
# 3    {'group-affiliation': 'former member of the cr...
# 4    {'group-affiliation': 'Cosmic Beings', 'relati...
# ..                                                 ...
# 725  {'group-affiliation': 'The Avengers, The West ...
# 726  {'group-affiliation': 'Formerly Guardians of t...
# 727  {'group-affiliation': '-', 'relatives': 'Utgar...
# 728  {'group-affiliation': 'Jedi Order, Jedi High C...
# 729  {'group-affiliation': 'Misty Kilgore, Seven So...
#
#                                                  image
# 0    {'url': 'https://www.superherodb.com/pictures2...
# 1    {'url': 'https://www.superherodb.com/pictures2...
# 2    {'url': 'https://www.superherodb.com/pictures2...
# 3    {'url': 'https://www.superherodb.com/pictures2...
# 4    {'url': 'https://www.superherodb.com/pictures2...
# ..                                                 ...
# 725  {'url': 'https://www.superherodb.com/pictures2...
# 726  {'url': 'https://www.superherodb.com/pictures2...
# 727  {'url': 'https://www.superherodb.com/pictures2...
# 728  {'url': 'https://www.superherodb.com/pictures2...
# 729  {'url': 'https://www.superherodb.com/pictures2...
#
# [730 rows x 9 columns]
